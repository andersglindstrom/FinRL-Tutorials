# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/1-Introduction/Stock_NeurIPS2018_SB3.py">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading
#
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Task Description](#0)
# * [2. Install Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. A List of Python Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download and Preprocess Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5. Build Market Environment in OpenAI Gym-style](#4)
#     * [5.1. Data Split](#4.1)
#     * [5.3. Environment for Training](#4.2)
# * [6. Train DRL Agents](#5)
# * [7. Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Task Discription

# %% [markdown]
# We train a DRL agent for stock trading. This task is modeled as a Markov Decision Process (MDP), and the objective function is maximizing (expected) cumulative return.
#
# We specify the state-action-reward as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes many features and learns by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying. When an action operates multiple shares, a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#
# **Market environment**: 30 consituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.
#
#
# The data for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Install Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install packages

# %%
## install required packages
# !pip install swig
# !pip install wrds
# !pip install pyportfolioopt
## install finrl library
# !pip install -q condacolab
import condacolab
condacolab.install()
# !apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting swig
#   Downloading swig-4.1.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 19.2 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.1.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wrds
#   Downloading wrds-3.1.6-py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from wrds) (1.22.4)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 27.1 MB/s eta 0:00:00
# Requirement already satisfied: sqlalchemy<2 in /usr/local/lib/python3.9/dist-packages (from wrds) (1.4.46)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from wrds) (1.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from wrds) (1.3.5)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy<2->wrds) (2.0.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas->wrds) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/dist-packages (from pandas->wrds) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7.3->pandas->wrds) (1.15.0)
# Installing collected packages: psycopg2-binary, wrds
# Successfully installed psycopg2-binary-2.9.5 wrds-3.1.6
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyportfolioopt
#   Downloading pyportfolioopt-1.5.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 KB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.9/dist-packages (from pyportfolioopt) (1.3.5)
# Requirement already satisfied: scipy<2.0,>=1.3 in /usr/local/lib/python3.9/dist-packages (from pyportfolioopt) (1.10.1)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in /usr/local/lib/python3.9/dist-packages (from pyportfolioopt) (1.22.4)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.10 in /usr/local/lib/python3.9/dist-packages (from pyportfolioopt) (1.2.3)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from cvxpy<2.0.0,>=1.1.10->pyportfolioopt) (0.6.2.post0)
# Requirement already satisfied: setuptools<=64.0.2 in /usr/local/lib/python3.9/dist-packages (from cvxpy<2.0.0,>=1.1.10->pyportfolioopt) (57.4.0)
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.9/dist-packages (from cvxpy<2.0.0,>=1.1.10->pyportfolioopt) (3.2.2)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.9/dist-packages (from cvxpy<2.0.0,>=1.1.10->pyportfolioopt) (2.0.12)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.19->pyportfolioopt) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.19->pyportfolioopt) (2022.7.1)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.9/dist-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.10->pyportfolioopt) (0.1.5.post3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pyportfolioopt) (1.15.0)
# Installing collected packages: pyportfolioopt
# Successfully installed pyportfolioopt-1.5.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /tmp/pip-req-build-hnlupdsm
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /tmp/pip-req-build-hnlupdsm
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit 4028be5daf1080300e3f8373427f197b248bed35
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-h67e5a0c/elegantrl_30347ace2a1e4c84ba0a208f84303f29
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-h67e5a0c/elegantrl_30347ace2a1e4c84ba0a208f84303f29
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 68bf0ea4ef3fb461026ece8897deabb92aeead32
#   Preparing metadata (setup.py) ... done
# Collecting pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2
#   Cloning https://github.com/quantopian/pyfolio.git to /tmp/pip-install-h67e5a0c/pyfolio_5ce1ff98319a4f278eb49cd7d1392f84
#   Running command git clone --filter=blob:none --quiet https://github.com/quantopian/pyfolio.git /tmp/pip-install-h67e5a0c/pyfolio_5ce1ff98319a4f278eb49cd7d1392f84
#   Resolved https://github.com/quantopian/pyfolio.git to commit 4b901f6d73aa02ceb6d04b7d83502e5c6f2e81aa
#   Preparing metadata (setup.py) ... done
# Collecting jqdatasdk
#   Downloading jqdatasdk-1.8.11-py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 KB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: gym>=0.17 in /usr/local/lib/python3.9/dist-packages (from finrl==0.3.5) (0.25.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from finrl==0.3.5) (1.22.4)
# Collecting stockstats>=0.4.0
#   Downloading stockstats-0.5.2-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: scikit-learn>=0.21.0 in /usr/local/lib/python3.9/dist-packages (from finrl==0.3.5) (1.2.1)
# Collecting stable-baselines3<2.0.0,>=1.6.2
#   Downloading stable_baselines3-1.7.0-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.8/171.8 KB 10.2 MB/s eta 0:00:00
# Collecting alpaca_trade_api>=2.1.0
#   Downloading alpaca_trade_api-3.0.0-py3-none-any.whl (33 kB)
# Collecting tensorboardX
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 KB 12.7 MB/s eta 0:00:00
# Collecting ray[default,tune]>=2.0.0
#   Downloading ray-2.3.0-cp39-cp39-manylinux2014_x86_64.whl (58.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 MB 9.1 MB/s eta 0:00:00
# Collecting yfinance
#   Downloading yfinance-0.2.12-py2.py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 KB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from finrl==0.3.5) (3.5.3)
# Collecting importlib-metadata==4.13.0
#   Downloading importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Collecting pandas_market_calendars==3.6.3
#   Downloading pandas_market_calendars-3.6.3.tar.gz (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.8/152.8 KB 18.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gputil
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting lz4
#   Downloading lz4-4.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.9/dist-packages (from finrl==0.3.5) (1.3.5)
# Collecting ccxt>=1.66.32
#   Downloading ccxt-2.9.11-py2.py3-none-any.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 85.2 MB/s eta 0:00:00
# Collecting pyluach
#   Downloading pyluach-2.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from pandas_market_calendars==3.6.3->finrl==0.3.5) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.9/dist-packages (from pandas_market_calendars==3.6.3->finrl==0.3.5) (2022.7.1)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from pandas_market_calendars==3.6.3->finrl==0.3.5) (0.12.0)
# Requirement already satisfied: korean_lunar_calendar in /usr/local/lib/python3.9/dist-packages (from pandas_market_calendars==3.6.3->finrl==0.3.5) (0.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata==4.13.0->finrl==0.3.5) (3.15.0)
# Requirement already satisfied: PyYAML==6.0 in /usr/local/lib/python3.9/dist-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (6.0)
# Requirement already satisfied: requests<3,>2 in /usr/local/lib/python3.9/dist-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (2.25.1)
# Collecting deprecation==2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting msgpack==1.0.3
#   Downloading msgpack-1.0.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 KB 30.3 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<2,>1.24 in /usr/local/lib/python3.9/dist-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.26.14)
# Collecting aiohttp==3.8.1
#   Downloading aiohttp-3.8.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 61.8 MB/s eta 0:00:00
# Collecting websocket-client<2,>=0.56.0
#   Downloading websocket_client-1.5.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 7.1 MB/s eta 0:00:00
# Collecting websockets<11,>=9.0
#   Downloading websockets-10.4-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 KB 12.4 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 28.1 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 11.6 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (22.2.0)
# Collecting charset-normalizer<3.0,>=2.0
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from deprecation==2.1.0->alpaca_trade_api>=2.1.0->finrl==0.3.5) (23.0)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.9/dist-packages (from ccxt>=1.66.32->finrl==0.3.5) (2022.12.7)
# Collecting aiodns>=1.1.1
#   Downloading aiodns-3.0.0-py3-none-any.whl (5.0 kB)
# Collecting cryptography>=2.6.1
#   Downloading cryptography-39.0.2-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 70.6 MB/s eta 0:00:00
# Collecting setuptools>=60.9.0
#   Downloading setuptools-67.6.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 49.8 MB/s eta 0:00:00
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.9/dist-packages (from gym>=0.17->finrl==0.3.5) (0.0.8)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from gym>=0.17->finrl==0.3.5) (2.2.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.9/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (3.19.6)
# Requirement already satisfied: grpcio>=1.32.0 in /usr/local/lib/python3.9/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (1.51.3)
# Collecting virtualenv>=20.0.24
#   Downloading virtualenv-20.20.0-py3-none-any.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 56.3 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.9/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (4.3.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (3.9.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (8.1.3)
# Collecting colorful
#   Downloading colorful-0.5.5-py2.py3-none-any.whl (201 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 KB 18.1 MB/s eta 0:00:00
# Collecting py-spy>=0.2.0
#   Downloading py_spy-0.3.14-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 64.8 MB/s eta 0:00:00
# Requirement already satisfied: pydantic in /usr/local/lib/python3.9/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (1.10.5)
# Collecting gpustat>=1.0.0
#   Downloading gpustat-1.0.0.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.5/90.5 KB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.9/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (0.16.0)
# Collecting opencensus
#   Downloading opencensus-0.11.2-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 KB 13.8 MB/s eta 0:00:00
# Requirement already satisfied: smart-open in /usr/local/lib/python3.9/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (6.3.0)
# Collecting aiohttp-cors
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (0.8.10)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (3.1.0)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.9/dist-packages (from stable-baselines3<2.0.0,>=1.6.2->finrl==0.3.5) (1.13.1+cu116)
# Collecting gym>=0.17
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 67.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from jqdatasdk->finrl==0.3.5) (1.15.0)
# Collecting pymysql>=0.7.6
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 KB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /usr/local/lib/python3.9/dist-packages (from jqdatasdk->finrl==0.3.5) (1.4.46)
# Collecting thriftpy2>=0.3.9
#   Downloading thriftpy2-0.4.16.tar.gz (643 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 643.4/643.4 KB 37.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->finrl==0.3.5) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->finrl==0.3.5) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->finrl==0.3.5) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->finrl==0.3.5) (4.39.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->finrl==0.3.5) (0.11.0)
# Requirement already satisfied: ipython>=3.2.3 in /usr/local/lib/python3.9/dist-packages (from pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (7.9.0)
# Requirement already satisfied: seaborn>=0.7.1 in /usr/local/lib/python3.9/dist-packages (from pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.11.2)
# Collecting empyrical>=0.5.0
#   Downloading empyrical-0.5.5.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 KB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.9/dist-packages (from yfinance->finrl==0.3.5) (4.9.2)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.9/dist-packages (from yfinance->finrl==0.3.5) (0.0.11)
# Collecting appdirs>=1.4.4
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting beautifulsoup4>=4.11.1
#   Downloading beautifulsoup4-4.11.2-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 15.9 MB/s eta 0:00:00
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.3.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.8/112.8 KB 12.1 MB/s eta 0:00:00
# Collecting requests<3,>2
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 6.4 MB/s eta 0:00:00
# Collecting html5lib>=1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 11.7 MB/s eta 0:00:00
# Collecting pycares>=4.0.0
#   Downloading pycares-4.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.7/288.7 KB 27.7 MB/s eta 0:00:00
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.4-py3-none-any.whl (37 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=2.6.1->ccxt>=1.66.32->finrl==0.3.5) (1.15.1)
# Requirement already satisfied: pandas-datareader>=0.2 in /usr/local/lib/python3.9/dist-packages (from empyrical>=0.5.0->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.9.0)
# Collecting nvidia-ml-py<=11.495.46,>=11.450.129
#   Downloading nvidia_ml_py-11.495.46-py3-none-any.whl (25 kB)
# Collecting psutil>=5.6.0
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 KB 24.2 MB/s eta 0:00:00
# Collecting blessed>=1.17.1
#   Downloading blessed-1.20.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 KB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from html5lib>=1.1->yfinance->finrl==0.3.5) (0.5.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.2.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (2.6.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (5.7.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (2.0.10)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.9 MB/s eta 0:00:00
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.7.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>2->alpaca_trade_api>=2.1.0->finrl==0.3.5) (2.10)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from SQLAlchemy>=1.2.8->jqdatasdk->finrl==0.3.5) (2.0.2)
# Collecting ply<4.0,>=3.4
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3<2.0.0,>=1.6.2->finrl==0.3.5) (4.5.0)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 KB 34.5 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs<4,>=2.4 in /usr/local/lib/python3.9/dist-packages (from virtualenv>=20.0.24->ray[default,tune]>=2.0.0->finrl==0.3.5) (3.1.0)
# Collecting gym[box2d]
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 KB 43.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.26.1.tar.gz (719 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.9/719.9 KB 46.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.26.0.tar.gz (710 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 710.3/710.3 KB 36.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.25.1.tar.gz (732 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 732.2/732.2 KB 52.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.25.0.tar.gz (720 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 720.4/720.4 KB 36.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.24.1.tar.gz (696 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 696.4/696.4 KB 35.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.24.0.tar.gz (694 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 694.4/694.4 KB 47.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.23.1.tar.gz (626 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 626.2/626.2 KB 39.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.23.0.tar.gz (624 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.4/624.4 KB 37.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.22.0.tar.gz (631 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 KB 33.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/box2d-py/
# Collecting box2d-py==2.3.5
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /packages/dd/5a/ad8d3ef9c13d5afcc1e44a77f11792ee717f6727b3320bddbc607e935e2a/box2d-py-2.3.5.tar.gz
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 KB 7.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyglet>=1.4.0
#   Downloading pyglet-2.0.5-py3-none-any.whl (831 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.3/831.3 KB 35.6 MB/s eta 0:00:00
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.19.3)
# Collecting opencensus-context>=0.1.3
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (2.11.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.9/dist-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.2.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt>=1.66.32->finrl==0.3.5) (2.21)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.9/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (1.58.0)
# Requirement already satisfied: google-auth<3.0dev,>=2.14.1 in /usr/local/lib/python3.9/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (2.16.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.7.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (4.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.4.8)
# Building wheels for collected packages: finrl, pandas_market_calendars, gym, elegantrl, gputil, pyfolio, empyrical, gpustat, thriftpy2, box2d-py
#   Building wheel for finrl (pyproject.toml) ... done
#   Created wheel for finrl: filename=finrl-0.3.5-py3-none-any.whl size=2860819 sha256=3dadd5b9398c485ce96cb11ac2cbcfa4d5301d42e680a0f38bb1da988f7106cc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nzt2g0py/wheels/ec/6a/08/c43694890a7c5a62c23af4b2a497bce5ee7edef607852cf53f
#   Building wheel for pandas_market_calendars (setup.py) ... done
#   Created wheel for pandas_market_calendars: filename=pandas_market_calendars-3.6.3-py3-none-any.whl size=182636 sha256=4c654489b079f990d82b39b6c8bb8cecee3893291427a9773bc20e9653313e17
#   Stored in directory: /root/.cache/pip/wheels/4e/02/f9/6c6eeb48a242879e357caf2813953fa8b6e26bd0110bd94226
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616821 sha256=da670b1fe81556d628bb3de6000c176261c781d8f732097c4b8bbe964c7d005a
#   Stored in directory: /root/.cache/pip/wheels/b3/50/6c/0a82c1358b4da2dbd9c1bb17e0f89467db32812ab236dbf6d5
#   Building wheel for elegantrl (setup.py) ... done
#   Created wheel for elegantrl: filename=elegantrl-0.3.6-py3-none-any.whl size=195057 sha256=648b8b3b915b381b1cc4b22bc014ac34009a9e6e3354b65d6c7c38d590235d68
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nzt2g0py/wheels/a3/c3/be/03eb1f20c8650f23ab13b823d93a297a917899f5d08b04b7b9
#   Building wheel for gputil (setup.py) ... done
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7409 sha256=128ea3d8b2e378550652045911996209c256563389960c1a391abad233dc5d85
#   Stored in directory: /root/.cache/pip/wheels/2b/b5/24/fbb56595c286984f7315ee31821d6121e1b9828436021a88b3
#   Building wheel for pyfolio (setup.py) ... done
#   Created wheel for pyfolio: filename=pyfolio-0.9.2+75.g4b901f6-py3-none-any.whl size=75774 sha256=304c3cf2274f97d49f88a0746ea7aedb94da76c8c9c362a20268c21fb3bf3b9d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nzt2g0py/wheels/da/0d/dd/aef7001cc1238aff04ec9eabfc002341f00c50deead3083855
#   Building wheel for empyrical (setup.py) ... done
#   Created wheel for empyrical: filename=empyrical-0.5.5-py3-none-any.whl size=39778 sha256=1f988e222ef6300c826b8694dc1773560944fb623b992b46e6590eebbe6b88e2
#   Stored in directory: /root/.cache/pip/wheels/67/23/d1/a4ef8ff88dc9af7b0eeb1b6fd0d90c6057eaad5a2df25f4e3f
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-1.0.0-py3-none-any.whl size=19887 sha256=a34eb61c162c83f5de438201e45b5ae3a9f87b8d2da3f6183bff03417e0459ef
#   Stored in directory: /root/.cache/pip/wheels/ce/13/aa/145d9d670feb2cf4a0691b9a3552aafc8a1b49c5162a0f379d
#   Building wheel for thriftpy2 (setup.py) ... done
#   Created wheel for thriftpy2: filename=thriftpy2-0.4.16-cp39-cp39-linux_x86_64.whl size=1210584 sha256=90ac29e8fbdfc03b58a41fcb53a19bc1af3bc0768e652f3a47606c60de564060
#   Stored in directory: /root/.cache/pip/wheels/88/a4/d5/907737b4c175aec82087b815fa93a8afea5c6c5a3e7bb748b9
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp39-cp39-linux_x86_64.whl size=2807958 sha256=71975db25ca4751c08184c13b0565f51aa5289c8ab90dc70f64fe24589b0bf71
#   Stored in directory: /root/.cache/pip/wheels/a4/c2/c1/076651c394f05fe60990cd85616c2d95bc1619aa113f559d7d
# Successfully built finrl pandas_market_calendars gym elegantrl gputil pyfolio empyrical gpustat thriftpy2 box2d-py
# Installing collected packages: pyglet, py-spy, ply, opencensus-context, nvidia-ml-py, msgpack, gputil, distlib, colorful, box2d-py, appdirs, websockets, websocket-client, virtualenv, thriftpy2, tensorboardX, soupsieve, setuptools, pymysql, pyluach, psutil, multidict, lz4, jedi, importlib-metadata, html5lib, gym, frozenlist, frozendict, deprecation, charset-normalizer, blessed, async-timeout, yarl, requests, pycares, gpustat, cryptography, beautifulsoup4, aiosignal, yfinance, stockstats, stable-baselines3, ray, jqdatasdk, pandas_market_calendars, elegantrl, aiohttp, aiodns, opencensus, empyrical, ccxt, alpaca_trade_api, aiohttp-cors, pyfolio, finrl
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.0.4
#     Uninstalling msgpack-1.0.4:
#       Successfully uninstalled msgpack-1.0.4
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.0.0
#     Uninstalling importlib-metadata-6.0.0:
#       Successfully uninstalled importlib-metadata-6.0.0
#   Attempting uninstall: html5lib
#     Found existing installation: html5lib 1.0.1
#     Uninstalling html5lib-1.0.1:
#       Successfully uninstalled html5lib-1.0.1
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cvxpy 1.2.3 requires setuptools<=64.0.2, but you have setuptools 67.6.0 which is incompatible.
# Successfully installed aiodns-3.0.0 aiohttp-3.8.1 aiohttp-cors-0.7.0 aiosignal-1.3.1 alpaca_trade_api-3.0.0 appdirs-1.4.4 async-timeout-4.0.2 beautifulsoup4-4.11.2 blessed-1.20.0 box2d-py-2.3.5 ccxt-2.9.11 charset-normalizer-2.1.1 colorful-0.5.5 cryptography-39.0.2 deprecation-2.1.0 distlib-0.3.6 elegantrl-0.3.6 empyrical-0.5.5 pandas_market_calendars-3.6.3 finrl-0.3.5 frozendict-2.3.5 frozenlist-1.3.3 gpustat-1.0.0 gputil-1.4.0 gym-0.21.0 html5lib-1.1 importlib-metadata-4.13.0 jedi-0.18.2 jqdatasdk-1.8.11 lz4-4.3.2 msgpack-1.0.3 multidict-6.0.4 nvidia-ml-py-11.495.46 opencensus-0.11.2 opencensus-context-0.1.3 ply-3.11 psutil-5.9.4 py-spy-0.3.14 pycares-4.3.0 pyfolio-0.9.2+75.g4b901f6 pyglet-2.0.5 pyluach-2.2.0 pymysql-1.0.2 ray-2.3.0 requests-2.28.2 setuptools-67.6.0 soupsieve-2.4 stable-baselines3-1.7.0 stockstats-0.5.2 tensorboardX-2.6 thriftpy2-0.4.16 virtualenv-20.20.0 websocket-client-1.5.1 websockets-10.4 yarl-1.8.2 yfinance-0.2.12

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. A list of Python packages
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl.meta.data_processor import DataProcessor

from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint

import sys
sys.path.append("../FinRL")

import itertools
# Out:
# /home/anders/miniconda3/lib/python3.13/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
from finrl import config
from finrl import config_tickers
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance provides stock data, financial news, financial reports, etc. Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** in FinRL-Meta to fetch data via Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()

# %%
# from config.py, TRAIN_START_DATE is a string
TRAIN_START_DATE
# from config.py, TRAIN_END_DATE is a string
TRAIN_END_DATE
# Out:
# '2020-07-31'

# %%
TRAIN_START_DATE = '2010-01-01'
TRAIN_END_DATE = '2021-10-01'
TRADE_START_DATE = '2021-10-01'
TRADE_END_DATE = '2023-03-01'

# %%
df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = config_tickers.DOW_30_TICKER).fetch_data()
# Out:
# YF deprecation warning: set proxy via new config function: yf.set_config(proxy=proxy)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (97013, 8)

# %%
print(config_tickers.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
df.shape
# Out:
# (97013, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
# Price        date      close       high        low       open     volume  \
# 0      2010-01-04   6.440331   6.455076   6.391278   6.422876  493729600
# 1      2010-01-04  40.265976  40.370616  39.456750  39.505582    5277400
# 2      2010-01-04  32.720379  32.864310  32.296582  32.632423    6894300
# 3      2010-01-04  43.777542  43.941181  42.702194  43.419094    6186700
# 4      2010-01-04  39.547821  39.980111  38.845348  38.939914    7325600
#
# Price   tic  day
# 0      AAPL    0
# 1      AMGN    0
# 2       AXP    0
# 3        BA    0
# 4       CAT    0

# %% [markdown]
# # Part 4: Preprocess Data
# We need to check for missing data and do feature engineering to convert the data point into a state.
# * **Adding technical indicators**. In practical trading, various information needs to be taken into account, such as historical prices, current holding shares, technical indicators, etc. Here, we demonstrate two trend-following technical indicators: MACD and RSI.
# * **Adding turbulence index**. Risk-aversion reflects whether an investor prefers to protect the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the turbulence index that measures extreme fluctuation of asset price.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=True,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3310, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)

# %%
processed_full.sort_values(['date','tic'],ignore_index=True).head(10)
# Out:
#          date   tic       close        high         low        open  \
# 0  2010-01-04  AAPL    6.440331    6.455076    6.391278    6.422876
# 1  2010-01-04  AMGN   40.265976   40.370616   39.456750   39.505582
# 2  2010-01-04   AXP   32.720379   32.864310   32.296582   32.632423
# 3  2010-01-04    BA   43.777542   43.941181   42.702194   43.419094
# 4  2010-01-04   CAT   39.547821   39.980111   38.845348   38.939914
# 5  2010-01-04   CRM   18.571922   18.748159   18.415544   18.519796
# 6  2010-01-04  CSCO   16.255329   16.354085   15.807633   15.873471
# 7  2010-01-04   CVX   43.122471   43.198832   42.631578   42.653392
# 8  2010-01-04   DIS   27.593046   28.178119   27.420967   27.963019
# 9  2010-01-04    GS  132.649902  133.546598  129.913820  130.327687
#
#         volume  day  macd   boll_ub   boll_lb  rsi_30     cci_30  dx_30  \
# 0  493729600.0  0.0   0.0  6.461645  6.430151   100.0  66.666667  100.0
# 1    5277400.0  0.0   0.0  6.461645  6.430151   100.0  66.666667  100.0
# 2    6894300.0  0.0   0.0  6.461645  6.430151   100.0  66.666667  100.0
# 3    6186700.0  0.0   0.0  6.461645  6.430151   100.0  66.666667  100.0
# 4    7325600.0  0.0   0.0  6.461645  6.430151   100.0  66.666667  100.0
# 5    7906000.0  0.0   0.0  6.461645  6.430151   100.0  66.666667  100.0
# 6   59853700.0  0.0   0.0  6.461645  6.430151   100.0  66.666667  100.0
# 7   10173800.0  0.0   0.0  6.461645  6.430151   100.0  66.666667  100.0
# 8   13700400.0  0.0   0.0  6.461645  6.430151   100.0  66.666667  100.0
# 9    9135000.0  0.0   0.0  6.461645  6.430151   100.0  66.666667  100.0
#
#    close_30_sma  close_60_sma        vix  turbulence
# 0      6.440331      6.440331  20.040001         0.0
# 1     40.265976     40.265976  20.040001         0.0
# 2     32.720379     32.720379  20.040001         0.0
# 3     43.777542     43.777542  20.040001         0.0
# 4     39.547821     39.547821  20.040001         0.0
# 5     18.571922     18.571922  20.040001         0.0
# 6     16.255329     16.255329  20.040001         0.0
# 7     43.122471     43.122471  20.040001         0.0
# 8     27.593046     27.593046  20.040001         0.0
# 9    132.649902    132.649902  20.040001         0.0

# %%
mvo_df = processed_full.sort_values(['date','tic'],ignore_index=True)[['date','tic','close']]

# %% [markdown]
# <a id='4'></a>
# # Part 5. Build A Market Environment in OpenAI Gym-style
# The training process involves observing stock price change, taking an action and reward's calculation. By interacting with the market environment, the agent will eventually derive a trading strategy that may maximize (expected) rewards.
#
# Our market environment, based on OpenAI Gym, simulates stock markets with historical market data.

# %% [markdown]
# ## Data Split
# We split the data into training set and testing set as follows:
#
# Training data period: 2009-01-01 to 2020-07-01
#
# Trading data period: 2020-07-01 to 2021-10-31

# %%
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 85753
# 10237

# %%
train.tail()
# Out:
#             date  tic       close        high         low        open  \
# 2956  2021-09-30  UNH  371.414093  383.533481  371.147943  381.632401
# 2956  2021-09-30    V  216.924591  222.806625  216.807734  221.628278
# 2956  2021-09-30   VZ   42.742081   43.137767   42.734168   43.129855
# 2956  2021-09-30  WBA   38.408337   39.943038   38.302213   39.828753
# 2956  2021-09-30  WMT   44.220188   44.965757   44.178946   44.619942
#
#           volume  day      macd     boll_ub     boll_lb     rsi_30  \
# 2956   3779900.0  3.0 -4.215706  406.339791  374.984611  40.895363
# 2956   7128500.0  3.0 -1.515436  225.179234  213.252823  44.079018
# 2956  18736600.0  3.0 -0.203777   43.718475   42.508788  41.824911
# 2956   6449400.0  3.0 -0.221534   42.405392   38.093746  44.613721
# 2956  22457700.0  3.0 -0.505126   47.482039   44.063716  40.165808
#
#           cci_30      dx_30  close_30_sma  close_60_sma        vix  turbulence
# 2956 -232.791637  41.350089    393.482307    392.988889  23.139999   24.871975
# 2956  -54.736747  19.487640    221.375696    227.976408  23.139999   24.871975
# 2956 -103.383226  21.332096     43.259641     43.717979  23.139999   24.871975
# 2956 -107.978460   0.109740     40.094058     39.195161  23.139999   24.871975
# 2956 -151.607984  45.326013     46.244331     45.887430  23.139999   24.871975

# %%
trade.head()
# Out:
#          date   tic       close        high         low        open  \
# 0  2021-10-01  AAPL  139.992493  140.257467  136.518448  139.256465
# 0  2021-10-01  AMGN  191.379227  191.996524  188.587986  191.083997
# 0  2021-10-01   AXP  165.851700  166.976822  160.645586  160.664660
# 0  2021-10-01    BA  226.000000  226.720001  220.600006  222.850006
# 0  2021-10-01   CAT  180.580658  182.011693  177.709287  179.251827
#
#        volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  94639600.0  4.0 -1.686476  153.831497  135.763076  46.927746 -142.138393
# 0   2629400.0  4.0 -2.907904  199.755660  187.186058  40.408584  -96.444367
# 0   3956000.0  4.0  2.217002  169.902245  145.535350  56.265117  117.704478
# 0   9113600.0  4.0  0.730320  226.909442  205.727561  51.614047  116.649440
# 0   3695500.0  4.0 -3.497999  197.692329  174.339360  41.999434 -111.971221
#
#        dx_30  close_30_sma  close_60_sma   vix  turbulence
# 0  41.705986    145.702433    144.809057  21.1  120.123381
# 0  35.031875    195.730693    203.825873  21.1  120.123381
# 0  15.682215    157.221232    159.408880  21.1  120.123381
# 0   2.027170    217.175334    221.968500  21.1  120.123381
# 0  36.142115    189.292061    192.682354  21.1  120.123381

# %%
INDICATORS
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for Training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**. Users are also encouraged to try **ElegantRL** and **Ray RLlib**.
# * FinRL includes fine-tuned standard DRL algorithms, such as DQN, DDPG, Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
agent = DRLAgent(env = env_train)

if_using_a2c = True
if_using_ddpg = True
if_using_ppo = True
if_using_td3 = True
if_using_sac = True

# %% [markdown]
# ### Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# ### Agent 1: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")

if if_using_a2c:
  # set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Logging to results/a2c
# /home/anders/miniconda3/lib/python3.13/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run A2C on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                             tb_log_name='a2c',
                             total_timesteps=50000) if if_using_a2c else None
# Out:
# -------------------------------------
# | time/                 |           |
# |    fps                | 128       |
# |    iterations         | 100       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -49.1     |
# |    reward             | -1.690047 |
# |    std                | 1         |
# |    value_loss         | 1.75      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 137        |
# |    iterations         | 200        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -0.00212   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -33.1      |
# |    reward             | -2.7625756 |
# |    std                | 1.01       |
# |    value_loss         | 0.874      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 144       |
# |    iterations         | 300       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -83.4     |
# |    reward             | -4.236134 |
# |    std                | 1.01      |
# |    value_loss         | 14.5      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 137       |
# |    iterations         | 400       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0.0155    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -211      |
# |    reward             | 2.3888805 |
# |    std                | 1         |
# |    value_loss         | 35.1      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 129         |
# |    iterations         | 500         |
# |    time_elapsed       | 19          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | -186        |
# |    reward             | -0.78502154 |
# |    std                | 1.01        |
# |    value_loss         | 18          |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 135         |
# |    iterations         | 600         |
# |    time_elapsed       | 22          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | 8.81        |
# |    reward             | -0.05938908 |
# |    std                | 1.01        |
# |    value_loss         | 0.0615      |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 137       |
# |    iterations         | 700       |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | 27.6      |
# |    reward             | -1.191379 |
# |    std                | 1.01      |
# |    value_loss         | 0.722     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 139       |
# |    iterations         | 800       |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 8.47      |
# |    reward             | -1.111376 |
# |    std                | 1.01      |
# |    value_loss         | 2.18      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 137       |
# |    iterations         | 900       |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0.0119    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 191       |
# |    reward             | 4.9184623 |
# |    std                | 1.01      |
# |    value_loss         | 34.3      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 136      |
# |    iterations         | 1000     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -41.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -433     |
# |    reward             | 7.013533 |
# |    std                | 1.01     |
# |    value_loss         | 262      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 139       |
# |    iterations         | 1100      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | 575       |
# |    reward             | -6.973476 |
# |    std                | 1.01      |
# |    value_loss         | 245       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 140       |
# |    iterations         | 1200      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -39.3     |
# |    reward             | -1.552825 |
# |    std                | 1.01      |
# |    value_loss         | 1.35      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 141         |
# |    iterations         | 1300        |
# |    time_elapsed       | 45          |
# |    total_timesteps    | 6500        |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1299        |
# |    policy_loss        | -56.2       |
# |    reward             | 0.122870125 |
# |    std                | 1.01        |
# |    value_loss         | 2.35        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 1400      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 188       |
# |    reward             | 1.1597247 |
# |    std                | 1.01      |
# |    value_loss         | 25.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 142        |
# |    iterations         | 1500       |
# |    time_elapsed       | 52         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | 73.6       |
# |    reward             | -2.4870634 |
# |    std                | 1.01       |
# |    value_loss         | 5.76       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 1600      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 67.4      |
# |    reward             | 0.7254849 |
# |    std                | 1.01      |
# |    value_loss         | 12.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 142        |
# |    iterations         | 1700       |
# |    time_elapsed       | 59         |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | 0.00108    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | 780        |
# |    reward             | 14.0406065 |
# |    std                | 1.01       |
# |    value_loss         | 443        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 141       |
# |    iterations         | 1800      |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0.177     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -90.7     |
# |    reward             | 0.9015622 |
# |    std                | 1.01      |
# |    value_loss         | 6.48      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 142        |
# |    iterations         | 1900       |
# |    time_elapsed       | 66         |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | -77.2      |
# |    reward             | 0.74817055 |
# |    std                | 1.01       |
# |    value_loss         | 4.33       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 2000      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 35        |
# |    reward             | 1.1796215 |
# |    std                | 1.01      |
# |    value_loss         | 2.27      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 2100      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | 80        |
# |    reward             | 3.7961698 |
# |    std                | 1.01      |
# |    value_loss         | 8.51      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 144        |
# |    iterations         | 2200       |
# |    time_elapsed       | 75         |
# |    total_timesteps    | 11000      |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2199       |
# |    policy_loss        | 122        |
# |    reward             | -1.0667378 |
# |    std                | 1.01       |
# |    value_loss         | 9.96       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 145      |
# |    iterations         | 2300     |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -41.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 400      |
# |    reward             | -7.3871  |
# |    std                | 1.01     |
# |    value_loss         | 111      |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 146         |
# |    iterations         | 2400        |
# |    time_elapsed       | 81          |
# |    total_timesteps    | 12000       |
# | train/                |             |
# |    entropy_loss       | -41.5       |
# |    explained_variance | -0.14       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2399        |
# |    policy_loss        | 99.4        |
# |    reward             | -0.12149104 |
# |    std                | 1.01        |
# |    value_loss         | 6.61        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 148       |
# |    iterations         | 2500      |
# |    time_elapsed       | 84        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | -15.3     |
# |    reward             | 0.6189941 |
# |    std                | 1.01      |
# |    value_loss         | 1.23      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 146        |
# |    iterations         | 2600       |
# |    time_elapsed       | 88         |
# |    total_timesteps    | 13000      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2599       |
# |    policy_loss        | 1.42       |
# |    reward             | 0.38380703 |
# |    std                | 1.01       |
# |    value_loss         | 0.984      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 144        |
# |    iterations         | 2700       |
# |    time_elapsed       | 93         |
# |    total_timesteps    | 13500      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2699       |
# |    policy_loss        | -7.47      |
# |    reward             | -2.9867065 |
# |    std                | 1.02       |
# |    value_loss         | 1.39       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 144       |
# |    iterations         | 2800      |
# |    time_elapsed       | 96        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | -14       |
# |    reward             | 2.8429751 |
# |    std                | 1.01      |
# |    value_loss         | 1.41      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 145        |
# |    iterations         | 2900       |
# |    time_elapsed       | 99         |
# |    total_timesteps    | 14500      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | -0.0218    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2899       |
# |    policy_loss        | 76.1       |
# |    reward             | 0.15876931 |
# |    std                | 1.02       |
# |    value_loss         | 7.76       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 145         |
# |    iterations         | 3000        |
# |    time_elapsed       | 103         |
# |    total_timesteps    | 15000       |
# | train/                |             |
# |    entropy_loss       | -41.7       |
# |    explained_variance | -0.0575     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2999        |
# |    policy_loss        | 19          |
# |    reward             | -0.82098776 |
# |    std                | 1.02        |
# |    value_loss         | 0.507       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 145        |
# |    iterations         | 3100       |
# |    time_elapsed       | 106        |
# |    total_timesteps    | 15500      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | -0.0117    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3099       |
# |    policy_loss        | -78.5      |
# |    reward             | 0.18859841 |
# |    std                | 1.02       |
# |    value_loss         | 6.8        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 144       |
# |    iterations         | 3200      |
# |    time_elapsed       | 110       |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | 251       |
# |    reward             | 1.6175445 |
# |    std                | 1.02      |
# |    value_loss         | 44.4      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 145        |
# |    iterations         | 3300       |
# |    time_elapsed       | 113        |
# |    total_timesteps    | 16500      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | -0.894     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3299       |
# |    policy_loss        | 99.6       |
# |    reward             | 0.16701442 |
# |    std                | 1.02       |
# |    value_loss         | 6.67       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 144         |
# |    iterations         | 3400        |
# |    time_elapsed       | 117         |
# |    total_timesteps    | 17000       |
# | train/                |             |
# |    entropy_loss       | -41.8       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3399        |
# |    policy_loss        | -220        |
# |    reward             | -0.86757046 |
# |    std                | 1.02        |
# |    value_loss         | 65.2        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 145        |
# |    iterations         | 3500       |
# |    time_elapsed       | 120        |
# |    total_timesteps    | 17500      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3499       |
# |    policy_loss        | 70         |
# |    reward             | -1.9100765 |
# |    std                | 1.02       |
# |    value_loss         | 7.23       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 145         |
# |    iterations         | 3600        |
# |    time_elapsed       | 123         |
# |    total_timesteps    | 18000       |
# | train/                |             |
# |    entropy_loss       | -41.9       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3599        |
# |    policy_loss        | -1.01       |
# |    reward             | -0.23857017 |
# |    std                | 1.03        |
# |    value_loss         | 0.0664      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 145         |
# |    iterations         | 3700        |
# |    time_elapsed       | 127         |
# |    total_timesteps    | 18500       |
# | train/                |             |
# |    entropy_loss       | -41.9       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3699        |
# |    policy_loss        | -15.3       |
# |    reward             | -0.03394344 |
# |    std                | 1.03        |
# |    value_loss         | 1.24        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 144        |
# |    iterations         | 3800       |
# |    time_elapsed       | 131        |
# |    total_timesteps    | 19000      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | 1.79e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3799       |
# |    policy_loss        | -12.1      |
# |    reward             | 0.73776954 |
# |    std                | 1.03       |
# |    value_loss         | 4.74       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 144       |
# |    iterations         | 3900      |
# |    time_elapsed       | 135       |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -77.9     |
# |    reward             | 0.7886419 |
# |    std                | 1.02      |
# |    value_loss         | 5.12      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 144        |
# |    iterations         | 4000       |
# |    time_elapsed       | 138        |
# |    total_timesteps    | 20000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3999       |
# |    policy_loss        | -181       |
# |    reward             | -3.9610186 |
# |    std                | 1.02       |
# |    value_loss         | 22.8       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 144        |
# |    iterations         | 4100       |
# |    time_elapsed       | 141        |
# |    total_timesteps    | 20500      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4099       |
# |    policy_loss        | 78.5       |
# |    reward             | -2.2055476 |
# |    std                | 1.02       |
# |    value_loss         | 6.19       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 144       |
# |    iterations         | 4200      |
# |    time_elapsed       | 145       |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | 17.9      |
# |    reward             | -1.695212 |
# |    std                | 1.02      |
# |    value_loss         | 0.672     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 144       |
# |    iterations         | 4300      |
# |    time_elapsed       | 148       |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | 56.4      |
# |    reward             | 1.5091395 |
# |    std                | 1.02      |
# |    value_loss         | 2.39      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 144       |
# |    iterations         | 4400      |
# |    time_elapsed       | 152       |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | 48.2      |
# |    reward             | -2.793828 |
# |    std                | 1.03      |
# |    value_loss         | 2.01      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 144       |
# |    iterations         | 4500      |
# |    time_elapsed       | 155       |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | 38.4      |
# |    reward             | 1.7058799 |
# |    std                | 1.03      |
# |    value_loss         | 1.46      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 145       |
# |    iterations         | 4600      |
# |    time_elapsed       | 158       |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | 114       |
# |    reward             | 0.7473957 |
# |    std                | 1.03      |
# |    value_loss         | 14.9      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 144        |
# |    iterations         | 4700       |
# |    time_elapsed       | 162        |
# |    total_timesteps    | 23500      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4699       |
# |    policy_loss        | -113       |
# |    reward             | -3.5128913 |
# |    std                | 1.03       |
# |    value_loss         | 9.5        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 145         |
# |    iterations         | 4800        |
# |    time_elapsed       | 165         |
# |    total_timesteps    | 24000       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4799        |
# |    policy_loss        | -12.7       |
# |    reward             | -0.16597997 |
# |    std                | 1.03        |
# |    value_loss         | 0.735       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 145         |
# |    iterations         | 4900        |
# |    time_elapsed       | 168         |
# |    total_timesteps    | 24500       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4899        |
# |    policy_loss        | -81.5       |
# |    reward             | -0.12748143 |
# |    std                | 1.03        |
# |    value_loss         | 4.95        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 145        |
# |    iterations         | 5000       |
# |    time_elapsed       | 171        |
# |    total_timesteps    | 25000      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4999       |
# |    policy_loss        | 13.9       |
# |    reward             | 0.48030898 |
# |    std                | 1.03       |
# |    value_loss         | 5.49       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 145       |
# |    iterations         | 5100      |
# |    time_elapsed       | 175       |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | -31.1     |
# |    reward             | 0.8576719 |
# |    std                | 1.03      |
# |    value_loss         | 2.64      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 144        |
# |    iterations         | 5200       |
# |    time_elapsed       | 179        |
# |    total_timesteps    | 26000      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5199       |
# |    policy_loss        | -330       |
# |    reward             | 0.24861075 |
# |    std                | 1.03       |
# |    value_loss         | 103        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 144       |
# |    iterations         | 5300      |
# |    time_elapsed       | 183       |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | 67.8      |
# |    reward             | -5.180031 |
# |    std                | 1.03      |
# |    value_loss         | 5.07      |
# -------------------------------------
# day: 2956, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 3561031.22
# total_reward: 2561031.22
# total_cost: 9155.93
# total_trades: 40289
# Sharpe: 0.719
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 144        |
# |    iterations         | 5400       |
# |    time_elapsed       | 186        |
# |    total_timesteps    | 27000      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5399       |
# |    policy_loss        | -45.5      |
# |    reward             | -0.7201026 |
# |    std                | 1.03       |
# |    value_loss         | 1.62       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 144       |
# |    iterations         | 5500      |
# |    time_elapsed       | 190       |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | 76.3      |
# |    reward             | 0.5352149 |
# |    std                | 1.03      |
# |    value_loss         | 3.86      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 144          |
# |    iterations         | 5600         |
# |    time_elapsed       | 194          |
# |    total_timesteps    | 28000        |
# | train/                |              |
# |    entropy_loss       | -42.1        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 5599         |
# |    policy_loss        | -39.6        |
# |    reward             | -0.111039445 |
# |    std                | 1.03         |
# |    value_loss         | 4.9          |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 144        |
# |    iterations         | 5700       |
# |    time_elapsed       | 197        |
# |    total_timesteps    | 28500      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5699       |
# |    policy_loss        | 60         |
# |    reward             | 0.81495035 |
# |    std                | 1.04       |
# |    value_loss         | 4.87       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 144         |
# |    iterations         | 5800        |
# |    time_elapsed       | 200         |
# |    total_timesteps    | 29000       |
# | train/                |             |
# |    entropy_loss       | -42.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5799        |
# |    policy_loss        | 82.2        |
# |    reward             | -0.28192988 |
# |    std                | 1.04        |
# |    value_loss         | 10.7        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 144        |
# |    iterations         | 5900       |
# |    time_elapsed       | 203        |
# |    total_timesteps    | 29500      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5899       |
# |    policy_loss        | 113        |
# |    reward             | -2.4509919 |
# |    std                | 1.04       |
# |    value_loss         | 12.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 144       |
# |    iterations         | 6000      |
# |    time_elapsed       | 207       |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5999      |
# |    policy_loss        | -153      |
# |    reward             | 0.7271939 |
# |    std                | 1.04      |
# |    value_loss         | 14.6      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 144        |
# |    iterations         | 6100       |
# |    time_elapsed       | 210        |
# |    total_timesteps    | 30500      |
# | train/                |            |
# |    entropy_loss       | -42.3      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6099       |
# |    policy_loss        | 11.8       |
# |    reward             | 0.26199827 |
# |    std                | 1.04       |
# |    value_loss         | 0.241      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 144        |
# |    iterations         | 6200       |
# |    time_elapsed       | 214        |
# |    total_timesteps    | 31000      |
# | train/                |            |
# |    entropy_loss       | -42.4      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6199       |
# |    policy_loss        | -176       |
# |    reward             | -2.6027148 |
# |    std                | 1.04       |
# |    value_loss         | 29.8       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 144        |
# |    iterations         | 6300       |
# |    time_elapsed       | 218        |
# |    total_timesteps    | 31500      |
# | train/                |            |
# |    entropy_loss       | -42.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6299       |
# |    policy_loss        | 60.3       |
# |    reward             | 0.22571582 |
# |    std                | 1.04       |
# |    value_loss         | 3.58       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 6400      |
# |    time_elapsed       | 222       |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | 115       |
# |    reward             | 2.4046543 |
# |    std                | 1.04      |
# |    value_loss         | 17.5      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 6500       |
# |    time_elapsed       | 226        |
# |    total_timesteps    | 32500      |
# | train/                |            |
# |    entropy_loss       | -42.4      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6499       |
# |    policy_loss        | 230        |
# |    reward             | -1.3779773 |
# |    std                | 1.05       |
# |    value_loss         | 40         |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 6600       |
# |    time_elapsed       | 230        |
# |    total_timesteps    | 33000      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | -0.0561    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6599       |
# |    policy_loss        | -134       |
# |    reward             | -1.4444805 |
# |    std                | 1.05       |
# |    value_loss         | 8.95       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 142         |
# |    iterations         | 6700        |
# |    time_elapsed       | 234         |
# |    total_timesteps    | 33500       |
# | train/                |             |
# |    entropy_loss       | -42.5       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6699        |
# |    policy_loss        | 43.3        |
# |    reward             | 0.106708355 |
# |    std                | 1.05        |
# |    value_loss         | 1.3         |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 6800       |
# |    time_elapsed       | 237        |
# |    total_timesteps    | 34000      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | 0.000368   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6799       |
# |    policy_loss        | 92.7       |
# |    reward             | -2.4888215 |
# |    std                | 1.05       |
# |    value_loss         | 6.09       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 6900      |
# |    time_elapsed       | 241       |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -42.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | 46.3      |
# |    reward             | 0.9167187 |
# |    std                | 1.05      |
# |    value_loss         | 11.8      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 7000      |
# |    time_elapsed       | 244       |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -42.6     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | 100       |
# |    reward             | 0.7963212 |
# |    std                | 1.05      |
# |    value_loss         | 5.55      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 142          |
# |    iterations         | 7100         |
# |    time_elapsed       | 248          |
# |    total_timesteps    | 35500        |
# | train/                |              |
# |    entropy_loss       | -42.5        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 7099         |
# |    policy_loss        | -5.35        |
# |    reward             | 0.0027489455 |
# |    std                | 1.05         |
# |    value_loss         | 0.028        |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 7200      |
# |    time_elapsed       | 251       |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | 0.0014    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | 13.8      |
# |    reward             | 1.6934681 |
# |    std                | 1.05      |
# |    value_loss         | 0.228     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 142        |
# |    iterations         | 7300       |
# |    time_elapsed       | 255        |
# |    total_timesteps    | 36500      |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7299       |
# |    policy_loss        | -34.7      |
# |    reward             | 0.16585962 |
# |    std                | 1.05       |
# |    value_loss         | 0.936      |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 142      |
# |    iterations         | 7400     |
# |    time_elapsed       | 259      |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -42.5    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | -85      |
# |    reward             | 0.26427  |
# |    std                | 1.05     |
# |    value_loss         | 6.76     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 7500      |
# |    time_elapsed       | 263       |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7499      |
# |    policy_loss        | 111       |
# |    reward             | 2.1200335 |
# |    std                | 1.05      |
# |    value_loss         | 7.72      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 7600      |
# |    time_elapsed       | 266       |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7599      |
# |    policy_loss        | -26.2     |
# |    reward             | 2.5967867 |
# |    std                | 1.05      |
# |    value_loss         | 1.1       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 7700      |
# |    time_elapsed       | 269       |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | 52.5      |
# |    reward             | 0.7327741 |
# |    std                | 1.05      |
# |    value_loss         | 1.66      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 142        |
# |    iterations         | 7800       |
# |    time_elapsed       | 273        |
# |    total_timesteps    | 39000      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7799       |
# |    policy_loss        | 46.3       |
# |    reward             | -1.0592853 |
# |    std                | 1.05       |
# |    value_loss         | 1.9        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 7900      |
# |    time_elapsed       | 276       |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7899      |
# |    policy_loss        | -41       |
# |    reward             | 2.4448783 |
# |    std                | 1.05      |
# |    value_loss         | 1.15      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 142      |
# |    iterations         | 8000     |
# |    time_elapsed       | 279      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -42.5    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7999     |
# |    policy_loss        | 72.4     |
# |    reward             | 1.393806 |
# |    std                | 1.05     |
# |    value_loss         | 4.25     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 8100      |
# |    time_elapsed       | 283       |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -42.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8099      |
# |    policy_loss        | -312      |
# |    reward             | 4.272966  |
# |    std                | 1.05      |
# |    value_loss         | 73.3      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 8200       |
# |    time_elapsed       | 286        |
# |    total_timesteps    | 41000      |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8199       |
# |    policy_loss        | -889       |
# |    reward             | -3.3585718 |
# |    std                | 1.05       |
# |    value_loss         | 454        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 142        |
# |    iterations         | 8300       |
# |    time_elapsed       | 290        |
# |    total_timesteps    | 41500      |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | 0.0462     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8299       |
# |    policy_loss        | -135       |
# |    reward             | -1.1999054 |
# |    std                | 1.05       |
# |    value_loss         | 14.9       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 8400      |
# |    time_elapsed       | 293       |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -42.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8399      |
# |    policy_loss        | -69.9     |
# |    reward             | 0.6557489 |
# |    std                | 1.05      |
# |    value_loss         | 3.97      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 8500      |
# |    time_elapsed       | 297       |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -42.7     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8499      |
# |    policy_loss        | -23.2     |
# |    reward             | 1.4399564 |
# |    std                | 1.06      |
# |    value_loss         | 1.23      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 8600      |
# |    time_elapsed       | 300       |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -42.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8599      |
# |    policy_loss        | 6.64      |
# |    reward             | 1.9782518 |
# |    std                | 1.06      |
# |    value_loss         | 0.68      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 8700      |
# |    time_elapsed       | 304       |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -42.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | -105      |
# |    reward             | 1.7253332 |
# |    std                | 1.06      |
# |    value_loss         | 9.46      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 8800       |
# |    time_elapsed       | 306        |
# |    total_timesteps    | 44000      |
# | train/                |            |
# |    entropy_loss       | -42.8      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8799       |
# |    policy_loss        | 44.6       |
# |    reward             | -2.6025882 |
# |    std                | 1.06       |
# |    value_loss         | 3.99       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 8900      |
# |    time_elapsed       | 310       |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -42.9     |
# |    explained_variance | -0.0547   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | 112       |
# |    reward             | 1.8660214 |
# |    std                | 1.06      |
# |    value_loss         | 7.45      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 9000       |
# |    time_elapsed       | 314        |
# |    total_timesteps    | 45000      |
# | train/                |            |
# |    entropy_loss       | -42.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8999       |
# |    policy_loss        | 130        |
# |    reward             | 0.44467592 |
# |    std                | 1.06       |
# |    value_loss         | 9.93       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 9100       |
# |    time_elapsed       | 318        |
# |    total_timesteps    | 45500      |
# | train/                |            |
# |    entropy_loss       | -42.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9099       |
# |    policy_loss        | 50.5       |
# |    reward             | -0.8837981 |
# |    std                | 1.07       |
# |    value_loss         | 1.51       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 143          |
# |    iterations         | 9200         |
# |    time_elapsed       | 321          |
# |    total_timesteps    | 46000        |
# | train/                |              |
# |    entropy_loss       | -42.9        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 9199         |
# |    policy_loss        | 105          |
# |    reward             | -0.043548357 |
# |    std                | 1.07         |
# |    value_loss         | 8.28         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 9300      |
# |    time_elapsed       | 325       |
# |    total_timesteps    | 46500     |
# | train/                |           |
# |    entropy_loss       | -42.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9299      |
# |    policy_loss        | 36.1      |
# |    reward             | 3.0762525 |
# |    std                | 1.06      |
# |    value_loss         | 1.01      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 142          |
# |    iterations         | 9400         |
# |    time_elapsed       | 329          |
# |    total_timesteps    | 47000        |
# | train/                |              |
# |    entropy_loss       | -42.9        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 9399         |
# |    policy_loss        | 119          |
# |    reward             | 0.0076656113 |
# |    std                | 1.06         |
# |    value_loss         | 21.5         |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 9500       |
# |    time_elapsed       | 331        |
# |    total_timesteps    | 47500      |
# | train/                |            |
# |    entropy_loss       | -42.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9499       |
# |    policy_loss        | 68.3       |
# |    reward             | 0.44552103 |
# |    std                | 1.07       |
# |    value_loss         | 2.97       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 143      |
# |    iterations         | 9600     |
# |    time_elapsed       | 335      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -43      |
# |    explained_variance | -0.085   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9599     |
# |    policy_loss        | 63.5     |
# |    reward             | -1.96798 |
# |    std                | 1.07     |
# |    value_loss         | 4.03     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 142        |
# |    iterations         | 9700       |
# |    time_elapsed       | 339        |
# |    total_timesteps    | 48500      |
# | train/                |            |
# |    entropy_loss       | -43        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9699       |
# |    policy_loss        | 10.6       |
# |    reward             | -1.5655587 |
# |    std                | 1.07       |
# |    value_loss         | 0.15       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 142        |
# |    iterations         | 9800       |
# |    time_elapsed       | 342        |
# |    total_timesteps    | 49000      |
# | train/                |            |
# |    entropy_loss       | -43        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9799       |
# |    policy_loss        | -242       |
# |    reward             | -1.2946976 |
# |    std                | 1.07       |
# |    value_loss         | 31.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 9900       |
# |    time_elapsed       | 345        |
# |    total_timesteps    | 49500      |
# | train/                |            |
# |    entropy_loss       | -43.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9899       |
# |    policy_loss        | 77.4       |
# |    reward             | -1.2739329 |
# |    std                | 1.07       |
# |    value_loss         | 3.99       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 10000     |
# |    time_elapsed       | 348       |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -43.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9999      |
# |    policy_loss        | 105       |
# |    reward             | -4.637372 |
# |    std                | 1.07      |
# |    value_loss         | 15.5      |
# -------------------------------------

# %% [markdown]
# ### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device
# Logging to results/ddpg

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None
# Out:
# day: 2956, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 4622234.99
# total_reward: 3622234.99
# total_cost: 1680.12
# total_trades: 41498
# Sharpe: 0.776
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 81        |
# |    time_elapsed    | 145       |
# |    total_timesteps | 11828     |
# | train/             |           |
# |    actor_loss      | -147      |
# |    critic_loss     | 23.1      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11727     |
# |    reward          | -8.094233 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 81        |
# |    time_elapsed    | 290       |
# |    total_timesteps | 23656     |
# | train/             |           |
# |    actor_loss      | -99.4     |
# |    critic_loss     | 12.4      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23555     |
# |    reward          | -8.094233 |
# ----------------------------------
# day: 2956, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 4781916.02
# total_reward: 3781916.02
# total_cost: 999.00
# total_trades: 41384
# Sharpe: 0.798
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 84        |
# |    time_elapsed    | 419       |
# |    total_timesteps | 35484     |
# | train/             |           |
# |    actor_loss      | -59.4     |
# |    critic_loss     | 4.92      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35383     |
# |    reward          | -8.094233 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 85        |
# |    time_elapsed    | 551       |
# |    total_timesteps | 47312     |
# | train/             |           |
# |    actor_loss      | -42       |
# |    critic_loss     | 2.94      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 47211     |
# |    reward          | -8.094233 |
# ----------------------------------

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to results/ppo
# /home/anders/miniconda3/lib/python3.13/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=50000) if if_using_ppo else None
# Out:
# ----------------------------------
# | time/              |           |
# |    fps             | 204       |
# |    iterations      | 1         |
# |    time_elapsed    | 10        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 0.6408276 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 2           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015831396 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00156     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.83        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0186     |
# |    reward               | 0.39174712  |
# |    std                  | 1           |
# |    value_loss           | 10.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 3            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0120906355 |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.2        |
# |    explained_variance   | -0.00434     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 25.4         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0184      |
# |    reward               | 1.5746257    |
# |    std                  | 1            |
# |    value_loss           | 50.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 197         |
# |    iterations           | 4           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016321015 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0103     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 22.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0189     |
# |    reward               | 2.0435014   |
# |    std                  | 1.01        |
# |    value_loss           | 55.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 5           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013252938 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.00932    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.68        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0192     |
# |    reward               | -1.9905692  |
# |    std                  | 1.01        |
# |    value_loss           | 20.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 6           |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.018754523 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.0312     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 32.8        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0173     |
# |    reward               | 0.27417535  |
# |    std                  | 1.01        |
# |    value_loss           | 62.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 192         |
# |    iterations           | 7           |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.022507068 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.00314    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 94.5        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0142     |
# |    reward               | 1.0568159   |
# |    std                  | 1.01        |
# |    value_loss           | 154         |
# -----------------------------------------
# day: 2956, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 4722706.35
# total_reward: 3722706.35
# total_cost: 363955.35
# total_trades: 80759
# Sharpe: 0.862
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 190         |
# |    iterations           | 8           |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.027764244 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.0263     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.5        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0174     |
# |    reward               | -2.4467382  |
# |    std                  | 1.01        |
# |    value_loss           | 26.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 190         |
# |    iterations           | 9           |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.024932703 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | 0.00139     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 23.9        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0171     |
# |    reward               | 1.124439    |
# |    std                  | 1.01        |
# |    value_loss           | 57.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 190         |
# |    iterations           | 10          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.016591763 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | 0.00159     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 62.7        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0147     |
# |    reward               | -0.50316846 |
# |    std                  | 1.01        |
# |    value_loss           | 128         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 11          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012285228 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | -0.00158    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 35.1        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0107     |
# |    reward               | -0.12288824 |
# |    std                  | 1.02        |
# |    value_loss           | 74.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 192         |
# |    iterations           | 12          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.019549817 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | -0.0289     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.45        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.018      |
# |    reward               | 0.9448606   |
# |    std                  | 1.02        |
# |    value_loss           | 18          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 13          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.027136803 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | 0.00113     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 25.1        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0155     |
# |    reward               | -0.09088267 |
# |    std                  | 1.02        |
# |    value_loss           | 62.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 14          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.018685883 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | -0.00622    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 21.1        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.015      |
# |    reward               | 5.688421    |
# |    std                  | 1.02        |
# |    value_loss           | 69.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 193        |
# |    iterations           | 15         |
# |    time_elapsed         | 158        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.03419508 |
# |    clip_fraction        | 0.319      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.8      |
# |    explained_variance   | 0.0348     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 8.57       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0146    |
# |    reward               | 0.4781105  |
# |    std                  | 1.02       |
# |    value_loss           | 18.1       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 193          |
# |    iterations           | 16           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.031131294  |
# |    clip_fraction        | 0.289        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.9        |
# |    explained_variance   | 0.00719      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 29.4         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0121      |
# |    reward               | -0.034337804 |
# |    std                  | 1.03         |
# |    value_loss           | 71.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 17          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.018917462 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | -0.00718    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 33.5        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0121     |
# |    reward               | -2.6494656  |
# |    std                  | 1.03        |
# |    value_loss           | 71.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 18          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.019861115 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | -0.00793    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.2        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0112     |
# |    reward               | -4.009254   |
# |    std                  | 1.03        |
# |    value_loss           | 28          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 195          |
# |    iterations           | 19           |
# |    time_elapsed         | 199          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.025127906  |
# |    clip_fraction        | 0.236        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42          |
# |    explained_variance   | 0.00914      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 27.2         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0126      |
# |    reward               | -0.107922316 |
# |    std                  | 1.03         |
# |    value_loss           | 87.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 196         |
# |    iterations           | 20          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.027070776 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.0162      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.68        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0119     |
# |    reward               | -2.5180464  |
# |    std                  | 1.03        |
# |    value_loss           | 40          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 197          |
# |    iterations           | 21           |
# |    time_elapsed         | 217          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.02060432   |
# |    clip_fraction        | 0.264        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.1        |
# |    explained_variance   | 0.0226       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 9.96         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0104      |
# |    reward               | -0.044807035 |
# |    std                  | 1.03         |
# |    value_loss           | 18.6         |
# ------------------------------------------
# day: 2956, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 4210994.75
# total_reward: 3210994.75
# total_cost: 324992.37
# total_trades: 77948
# Sharpe: 0.786
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 197         |
# |    iterations           | 22          |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.021144694 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | 0.00367     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 27.6        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0144     |
# |    reward               | 0.013860563 |
# |    std                  | 1.03        |
# |    value_loss           | 47.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 198         |
# |    iterations           | 23          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.023455128 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | 0.0231      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 51.5        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0124     |
# |    reward               | -1.5868704  |
# |    std                  | 1.04        |
# |    value_loss           | 74.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 198         |
# |    iterations           | 24          |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.025718609 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | 0.0114      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 42.1        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0113     |
# |    reward               | -0.97731125 |
# |    std                  | 1.04        |
# |    value_loss           | 69.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 197         |
# |    iterations           | 25          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.022817146 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.3       |
# |    explained_variance   | -0.00243    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.43        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0194     |
# |    reward               | 1.9987817   |
# |    std                  | 1.04        |
# |    value_loss           | 21.8        |
# -----------------------------------------

# %% [markdown]
# ### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cuda device
# Logging to results/td3

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=50000) if if_using_td3 else None
# Out:
# -----------------------------------
# | time/              |            |
# |    episodes        | 4          |
# |    fps             | 142        |
# |    time_elapsed    | 82         |
# |    total_timesteps | 11828      |
# | train/             |            |
# |    actor_loss      | 45.1       |
# |    critic_loss     | 32.5       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 11727      |
# |    reward          | -10.054026 |
# -----------------------------------
# day: 2956, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 6248823.13
# total_reward: 5248823.13
# total_cost: 1289.06
# total_trades: 53264
# Sharpe: 0.979
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 8          |
# |    fps             | 140        |
# |    time_elapsed    | 168        |
# |    total_timesteps | 23656      |
# | train/             |            |
# |    actor_loss      | 56.4       |
# |    critic_loss     | 12.1       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 23555      |
# |    reward          | -10.054026 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 12         |
# |    fps             | 140        |
# |    time_elapsed    | 252        |
# |    total_timesteps | 35484      |
# | train/             |            |
# |    actor_loss      | 44.4       |
# |    critic_loss     | 11         |
# |    learning_rate   | 0.001      |
# |    n_updates       | 35383      |
# |    reward          | -10.054026 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 16         |
# |    fps             | 139        |
# |    time_elapsed    | 338        |
# |    total_timesteps | 47312      |
# | train/             |            |
# |    actor_loss      | 34.5       |
# |    critic_loss     | 13.7       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 47211      |
# |    reward          | -10.054026 |
# -----------------------------------

# %% [markdown]
# ### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cuda device
# Logging to results/sac

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=50000) if if_using_sac else None
# Out:
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 103       |
# |    time_elapsed    | 114       |
# |    total_timesteps | 11828     |
# | train/             |           |
# |    actor_loss      | 1.23e+03  |
# |    critic_loss     | 131       |
# |    ent_coef        | 0.224     |
# |    ent_coef_loss   | -57.3     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 11727     |
# |    reward          | -9.280884 |
# ----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 8          |
# |    fps             | 104        |
# |    time_elapsed    | 226        |
# |    total_timesteps | 23656      |
# | train/             |            |
# |    actor_loss      | 441        |
# |    critic_loss     | 165        |
# |    ent_coef        | 0.0698     |
# |    ent_coef_loss   | -116       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 23555      |
# |    reward          | -7.3278394 |
# -----------------------------------
# day: 2956, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 4276850.30
# total_reward: 3276850.30
# total_cost: 10391.19
# total_trades: 53044
# Sharpe: 0.678
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 104       |
# |    time_elapsed    | 339       |
# |    total_timesteps | 35484     |
# | train/             |           |
# |    actor_loss      | 219       |
# |    critic_loss     | 19.9      |
# |    ent_coef        | 0.0219    |
# |    ent_coef_loss   | -130      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 35383     |
# |    reward          | -8.030181 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 103       |
# |    time_elapsed    | 455       |
# |    total_timesteps | 47312     |
# | train/             |           |
# |    actor_loss      | 115       |
# |    critic_loss     | 7.87      |
# |    ent_coef        | 0.00697   |
# |    ent_coef_loss   | -107      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 47211     |
# |    reward          | -8.212856 |
# ----------------------------------

# %% [markdown]
# ## In-sample Performance
#
# Assume that the initial capital is $1,000,000.

# %% [markdown]
# ### Set turbulence threshold
# Set the turbulence threshold to be greater than the maximum of insample turbulence data. If current turbulence index is greater than the threshold, then we assume that the current market is volatile

# %%
data_risk_indicator = processed_full[(processed_full.date<TRAIN_END_DATE) & (processed_full.date>=TRAIN_START_DATE)]
insample_risk_indicator = data_risk_indicator.drop_duplicates(subset=['date'])

# %%
insample_risk_indicator.vix.describe()
# Out:
# count    2957.000000
# mean       18.105293
# std         7.272476
# min         9.140000
# 25%        13.370000
# 50%        16.209999
# 75%        20.629999
# max        82.690002
# Name: vix, dtype: float64

# %%
insample_risk_indicator.vix.quantile(0.996)
# Out:
# np.float64(57.212001831054636)

# %%
insample_risk_indicator.turbulence.describe()
# Out:
# count    2957.000000
# mean       34.139593
# std        43.879113
# min         0.000000
# 25%        14.613336
# 50%        23.644110
# 75%        38.292844
# max       652.509036
# Name: turbulence, dtype: float64

# %%
insample_risk_indicator.turbulence.quantile(0.996)
# Out:
# np.float64(291.72328775570406)

# %% [markdown]
# ### Trading (Out-of-sample Performance)
#
# We update periodically in order to take full advantage of the data, e.g., retrain quarterly, monthly or weekly. We also tune the parameters along the way, in this notebook we use the in-sample data from 2009-01 to 2020-07 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
trade.head()
# Out:
#          date   tic       close        high         low        open  \
# 0  2021-10-01  AAPL  139.992493  140.257467  136.518448  139.256465
# 0  2021-10-01  AMGN  191.379227  191.996524  188.587986  191.083997
# 0  2021-10-01   AXP  165.851700  166.976822  160.645586  160.664660
# 0  2021-10-01    BA  226.000000  226.720001  220.600006  222.850006
# 0  2021-10-01   CAT  180.580658  182.011693  177.709287  179.251827
#
#        volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  94639600.0  4.0 -1.686476  153.831497  135.763076  46.927746 -142.138393
# 0   2629400.0  4.0 -2.907904  199.755660  187.186058  40.408584  -96.444367
# 0   3956000.0  4.0  2.217002  169.902245  145.535350  56.265117  117.704478
# 0   9113600.0  4.0  0.730320  226.909442  205.727561  51.614047  116.649440
# 0   3695500.0  4.0 -3.497999  197.692329  174.339360  41.999434 -111.971221
#
#        dx_30  close_30_sma  close_60_sma   vix  turbulence
# 0  41.705986    145.702433    144.809057  21.1  120.123381
# 0  35.031875    195.730693    203.825873  21.1  120.123381
# 0  15.682215    157.221232    159.408880  21.1  120.123381
# 0   2.027170    217.175334    221.968500  21.1  120.123381
# 0  36.142115    189.292061    192.682354  21.1  120.123381

# %%
trained_moedl = trained_a2c
df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
    model=trained_moedl, 
    environment = e_trade_gym)
# Out:
# hit end!

# %%
trained_moedl = trained_ddpg
df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
    model=trained_moedl, 
    environment = e_trade_gym)
# Out:
# hit end!

# %%
trained_moedl = trained_ppo
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_moedl, 
    environment = e_trade_gym)
# Out:
# hit end!

# %%
trained_moedl = trained_td3
df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
    model=trained_moedl, 
    environment = e_trade_gym)
# Out:
# hit end!

# %%
trained_moedl = trained_sac
df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
    model=trained_moedl, 
    environment = e_trade_gym)
# Out:
# hit end!

# %%
df_account_value_a2c.shape
# Out:
# (353, 2)

# %% [markdown]
# <a id='7'></a>
# # Part 6.5: Mean Variance Optimization

# %%
mvo_df.head()
# Out:
#          date   tic      close
# 0  2010-01-04  AAPL   6.440331
# 1  2010-01-04  AMGN  40.265976
# 2  2010-01-04   AXP  32.720379
# 3  2010-01-04    BA  43.777542
# 4  2010-01-04   CAT  39.547821

# %%
fst = mvo_df
fst = fst.iloc[0*29:0*29+29, :]
tic = fst['tic'].tolist()

mvo = pd.DataFrame()

for k in range(len(tic)):
  mvo[tic[k]] = 0

for i in range(mvo_df.shape[0]//29):
  n = mvo_df
  n = n.iloc[i*29:i*29+29, :]
  date = n['date'][i*29]
  mvo.loc[date] = n['close'].tolist()

# %%
mvo.shape[0]
# Out:
# 3310

# %% [markdown]
# ### Helper functions

# %%
from scipy import optimize 
from scipy.optimize import linprog

#function obtains maximal return portfolio using linear programming

def MaximizeReturns(MeanReturns, PortfolioSize):
    
  #dependencies
  
    
  c = (np.multiply(-1, MeanReturns))
  A = np.ones([PortfolioSize,1]).T
  b=[1]
  res = linprog(c, A_ub = A, b_ub = b, bounds = (0,1), method = 'simplex') 
    
  return res

def MinimizeRisk(CovarReturns, PortfolioSize):
    
  def f(x, CovarReturns):
    func = np.matmul(np.matmul(x, CovarReturns), x.T) 
    return func

  def constraintEq(x):
    A=np.ones(x.shape)
    b=1
    constraintVal = np.matmul(A,x.T)-b 
    return constraintVal
    
  xinit=np.repeat(0.1, PortfolioSize)
  cons = ({'type': 'eq', 'fun':constraintEq})
  lb = 0
  ub = 1
  bnds = tuple([(lb,ub) for x in xinit])

  opt = optimize.minimize (f, x0 = xinit, args = (CovarReturns),  bounds = bnds, \
                             constraints = cons, tol = 10**-3)
    
  return opt

def MinimizeRiskConstr(MeanReturns, CovarReturns, PortfolioSize, R):
    
  def  f(x,CovarReturns):
         
    func = np.matmul(np.matmul(x,CovarReturns ), x.T)
    return func

  def constraintEq(x):
    AEq=np.ones(x.shape)
    bEq=1
    EqconstraintVal = np.matmul(AEq,x.T)-bEq 
    return EqconstraintVal
    
  def constraintIneq(x, MeanReturns, R):
    AIneq = np.array(MeanReturns)
    bIneq = R
    IneqconstraintVal = np.matmul(AIneq,x.T) - bIneq
    return IneqconstraintVal
    

  xinit=np.repeat(0.1, PortfolioSize)
  cons = ({'type': 'eq', 'fun':constraintEq},
          {'type':'ineq', 'fun':constraintIneq, 'args':(MeanReturns,R) })
  lb = 0
  ub = 1
  bnds = tuple([(lb,ub) for x in xinit])

  opt = optimize.minimize (f, args = (CovarReturns), method ='trust-constr',  \
                x0 = xinit,   bounds = bnds, constraints = cons, tol = 10**-3)
    
  return opt

# %%
def StockReturnsComputing(StockPrice, Rows, Columns): 
  import numpy as np 
  StockReturn = np.zeros([Rows-1, Columns]) 
  for j in range(Columns):        # j: Assets 
    for i in range(Rows-1):     # i: Daily Prices 
      StockReturn[i,j]=((StockPrice[i+1, j]-StockPrice[i,j])/StockPrice[i,j])* 100 
      
  return StockReturn

# %% [markdown]
# ### Calculate mean returns and variance-covariance matrix

# %%
# Obtain optimal portfolio sets that maximize return and minimize risk

#Dependencies
import numpy as np
import pandas as pd


#input k-portfolio 1 dataset comprising 15 stocks
# StockFileName = './DJIA_Apr112014_Apr112019_kpf1.csv'

Rows = 1259  #excluding header
Columns = 15  #excluding date
portfolioSize = 29 #set portfolio size

#read stock prices in a dataframe
# df = pd.read_csv(StockFileName,  nrows= Rows)

#extract asset labels
# assetLabels = df.columns[1:Columns+1].tolist()
# print(assetLabels)

#extract asset prices
# StockData = df.iloc[0:, 1:]
StockData = mvo.head(mvo.shape[0]-336)
TradeData = mvo.tail(336)
# df.head()
TradeData.to_numpy()
# Out:
# array([[146.53826904, 186.69134521, 172.96459961, ...,  42.50497055,
#          39.43691635,  47.19295502],
#        [146.07702637, 184.81260681, 170.17347717, ...,  42.14462662,
#          38.4654808 ,  46.80588913],
#        [149.72767639, 185.34046936, 166.90440369, ...,  42.2807579 ,
#          38.44915771,  47.09777069],
#        ...,
#        [147.90838623, 223.08778381, 170.17015076, ...,  33.05427933,
#          31.63903236,  45.97296524],
#        [145.24525452, 219.3699646 , 169.30543518, ...,  33.23443222,
#          31.28079033,  46.09590912],
#        [146.44317627, 220.11164856, 168.38235474, ...,  33.35453796,
#          30.92254448,  45.76266098]], shape=(336, 29))

# %%
#compute asset returns
arStockPrices = np.asarray(StockData)
[Rows, Cols]=arStockPrices.shape
arReturns = StockReturnsComputing(arStockPrices, Rows, Cols)


#compute mean returns and variance covariance matrix of returns
meanReturns = np.mean(arReturns, axis = 0)
covReturns = np.cov(arReturns, rowvar=False)
 
#set precision for printing results
np.set_printoptions(precision=3, suppress = True)

#display mean returns and variance-covariance matrix of returns
print('Mean returns of assets in k-portfolio 1\n', meanReturns)
print('Variance-Covariance matrix of returns\n', covReturns)
# Out:
# Mean returns of assets in k-portfolio 1
#  [0.121 0.063 0.073 0.078 0.069 0.118 0.052 0.043 0.073 0.052 0.106 0.078
#  0.022 0.057 0.049 0.073 0.04  0.063 0.046 0.05  0.098 0.096 0.046 0.059
#  0.109 0.095 0.042 0.035 0.051]
# Variance-Covariance matrix of returns
#  [[3.128 1.014 1.29  1.521 1.371 1.689 1.375 1.125 1.088 1.374 1.163 1.221
#   1.03  1.525 0.692 1.269 0.664 0.816 1.029 0.733 1.576 1.139 0.668 0.86
#   1.144 1.338 0.525 0.908 0.635]
#  [1.014 2.4   1.072 1.01  1.066 1.211 1.025 0.965 0.937 1.122 0.978 1.029
#   0.851 1.153 0.891 1.14  0.641 0.664 0.906 1.072 1.088 0.873 0.724 0.854
#   1.146 1.056 0.631 1.025 0.645]
#  [1.29  1.072 3.315 2.475 1.907 1.568 1.428 1.922 1.715 2.237 1.376 1.847
#   1.343 1.508 0.861 2.37  0.99  1.075 1.375 0.964 1.357 1.418 0.728 1.505
#   1.417 1.8   0.748 1.216 0.584]
#  [1.521 1.01  2.475 4.962 2.117 1.687 1.511 2.142 1.838 2.201 1.527 2.121
#   1.532 1.699 0.905 2.296 1.117 1.195 1.461 0.949 1.437 1.573 0.748 1.604
#   1.472 1.716 0.734 1.362 0.603]
#  [1.371 1.066 1.907 2.117 3.331 1.613 1.519 1.887 1.471 1.998 1.239 1.868
#   1.355 1.566 0.826 2.039 0.848 0.855 1.585 0.918 1.331 1.292 0.682 1.269
#   1.221 1.408 0.739 1.226 0.613]
#  [1.689 1.211 1.568 1.687 1.613 5.041 1.65  1.257 1.352 1.604 1.358 1.44
#   1.185 1.637 0.756 1.564 0.738 0.984 1.151 0.91  1.853 1.493 0.657 1.042
#   1.204 1.722 0.563 1.017 0.621]
#  [1.375 1.025 1.428 1.511 1.519 1.65  2.796 1.303 1.264 1.5   1.133 1.355
#   1.245 1.583 0.843 1.511 0.728 0.823 1.215 0.881 1.481 1.145 0.74  1.002
#   1.098 1.31  0.655 1.065 0.686]
#  [1.125 0.965 1.922 2.142 1.887 1.257 1.303 2.92  1.389 1.826 1.201 1.64
#   1.275 1.386 0.836 1.942 0.919 0.993 1.263 0.963 1.203 1.136 0.686 1.361
#   1.296 1.381 0.74  1.06  0.518]
#  [1.088 0.937 1.715 1.838 1.471 1.352 1.264 1.389 2.458 1.614 1.152 1.464
#   1.058 1.228 0.701 1.68  0.829 0.863 1.117 0.775 1.15  1.197 0.663 1.097
#   1.058 1.313 0.66  0.994 0.574]
#  [1.374 1.122 2.237 2.201 1.998 1.604 1.5   1.826 1.614 3.375 1.351 1.724
#   1.317 1.564 0.83  2.724 0.825 0.939 1.41  0.959 1.418 1.32  0.693 1.496
#   1.383 1.53  0.717 1.231 0.615]
#  [1.163 0.978 1.376 1.527 1.239 1.358 1.133 1.201 1.152 1.351 2.058 1.239
#   0.99  1.243 0.691 1.364 0.73  0.91  1.032 0.762 1.205 1.202 0.691 1.078
#   1.14  1.207 0.628 0.915 0.723]
#  [1.221 1.029 1.847 2.121 1.868 1.44  1.355 1.64  1.464 1.724 1.239 2.179
#   1.209 1.36  0.827 1.822 0.91  0.925 1.413 0.898 1.249 1.301 0.694 1.25
#   1.255 1.407 0.694 1.142 0.575]
#  [1.03  0.851 1.343 1.532 1.355 1.185 1.245 1.275 1.058 1.317 0.99  1.209
#   2.009 1.281 0.706 1.37  0.77  0.749 1.08  0.782 1.123 0.947 0.664 0.995
#   1.003 1.106 0.644 0.958 0.541]
#  [1.525 1.153 1.508 1.699 1.566 1.637 1.583 1.386 1.228 1.564 1.243 1.36
#   1.281 3.282 0.787 1.563 0.786 0.798 1.18  0.857 1.695 1.123 0.722 1.122
#   1.148 1.329 0.674 1.083 0.7  ]
#  [0.692 0.891 0.861 0.905 0.826 0.756 0.843 0.836 0.701 0.83  0.691 0.827
#   0.706 0.787 1.121 0.878 0.611 0.561 0.788 0.777 0.784 0.683 0.637 0.693
#   0.833 0.795 0.566 0.779 0.521]
#  [1.269 1.14  2.37  2.296 2.039 1.564 1.511 1.942 1.68  2.724 1.364 1.822
#   1.37  1.563 0.878 3.233 0.93  0.961 1.43  1.024 1.376 1.344 0.737 1.621
#   1.4   1.559 0.807 1.285 0.635]
#  [0.664 0.641 0.99  1.117 0.848 0.738 0.728 0.919 0.829 0.825 0.73  0.91
#   0.77  0.786 0.611 0.93  1.195 0.653 0.759 0.634 0.744 0.733 0.689 0.832
#   0.735 0.807 0.59  0.681 0.489]
#  [0.816 0.664 1.075 1.195 0.855 0.984 0.823 0.993 0.863 0.939 0.91  0.925
#   0.749 0.798 0.561 0.961 0.653 1.421 0.75  0.641 0.874 0.907 0.543 0.888
#   0.808 0.943 0.481 0.605 0.468]
#  [1.029 0.906 1.375 1.461 1.585 1.151 1.215 1.263 1.117 1.41  1.032 1.413
#   1.08  1.18  0.788 1.43  0.759 0.75  1.822 0.755 1.027 1.036 0.649 1.03
#   1.004 1.119 0.63  1.024 0.557]
#  [0.733 1.072 0.964 0.949 0.918 0.91  0.881 0.963 0.775 0.959 0.762 0.898
#   0.782 0.857 0.777 1.024 0.634 0.641 0.755 1.69  0.853 0.754 0.621 0.821
#   0.921 0.888 0.629 0.784 0.518]
#  [1.576 1.088 1.357 1.437 1.331 1.853 1.481 1.203 1.15  1.418 1.205 1.249
#   1.123 1.695 0.784 1.376 0.744 0.874 1.027 0.853 2.495 1.16  0.751 0.989
#   1.19  1.407 0.636 0.963 0.704]
#  [1.139 0.873 1.418 1.573 1.292 1.493 1.145 1.136 1.197 1.32  1.202 1.301
#   0.947 1.123 0.683 1.344 0.733 0.907 1.036 0.754 1.16  2.688 0.628 0.981
#   1.086 1.275 0.561 0.879 0.582]
#  [0.668 0.724 0.728 0.748 0.682 0.657 0.74  0.686 0.663 0.693 0.691 0.694
#   0.664 0.722 0.637 0.737 0.689 0.543 0.649 0.621 0.751 0.628 1.146 0.676
#   0.666 0.69  0.576 0.689 0.601]
#  [0.86  0.854 1.505 1.604 1.269 1.042 1.002 1.361 1.097 1.496 1.078 1.25
#   0.995 1.122 0.693 1.621 0.832 0.888 1.03  0.821 0.989 0.981 0.676 1.974
#   1.089 1.116 0.7   0.922 0.588]
#  [1.144 1.146 1.417 1.472 1.221 1.204 1.098 1.296 1.058 1.383 1.14  1.255
#   1.003 1.148 0.833 1.4   0.735 0.808 1.004 0.921 1.19  1.086 0.666 1.089
#   2.628 1.185 0.61  1.003 0.618]
#  [1.338 1.056 1.8   1.716 1.408 1.722 1.31  1.381 1.313 1.53  1.207 1.407
#   1.106 1.329 0.795 1.559 0.807 0.943 1.119 0.888 1.407 1.275 0.69  1.116
#   1.185 2.579 0.606 0.924 0.572]
#  [0.525 0.631 0.748 0.734 0.739 0.563 0.655 0.74  0.66  0.717 0.628 0.694
#   0.644 0.674 0.566 0.807 0.59  0.481 0.63  0.629 0.636 0.561 0.576 0.7
#   0.61  0.606 1.194 0.662 0.51 ]
#  [0.908 1.025 1.216 1.362 1.226 1.017 1.065 1.06  0.994 1.231 0.915 1.142
#   0.958 1.083 0.779 1.285 0.681 0.605 1.024 0.784 0.963 0.879 0.689 0.922
#   1.003 0.924 0.662 3.14  0.709]
#  [0.635 0.645 0.584 0.603 0.613 0.621 0.686 0.518 0.574 0.615 0.723 0.575
#   0.541 0.7   0.521 0.635 0.489 0.468 0.557 0.518 0.704 0.582 0.601 0.588
#   0.618 0.572 0.51  0.709 1.406]]

# %%
from pypfopt.efficient_frontier import EfficientFrontier

ef_mean = EfficientFrontier(meanReturns, covReturns, weight_bounds=(0, 0.5))
raw_weights_mean = ef_mean.max_sharpe()
cleaned_weights_mean = ef_mean.clean_weights()
mvo_weights = np.array([1000000 * cleaned_weights_mean[i] for i in range(29)])
mvo_weights
# Out:
# array([229900.,      0.,      0.,      0.,      0.,  49780.,      0.,
#             0.,      0.,      0., 303790.,      0.,      0.,      0.,
#             0.,      0.,      0.,   2930.,      0.,      0.,  20720.,
#         94130.,      0.,      0., 230500.,  29090.,      0.,      0.,
#         39150.])

# %%
StockData.tail(1)
# Out:
#                   AAPL        AMGN         AXP          BA         CAT  \
# 2021-10-25  145.870911  185.752014  174.264618  212.869995  188.940659
#
#                    CRM       CSCO        CVX        DIS          GS  ...  \
# 2021-10-25  291.828918  49.565731  99.112343  169.91098  378.527252  ...
#
#                   MRK        MSFT         NKE          PG         TRV  \
# 2021-10-25  73.578651  299.192261  156.620316  129.181717  150.399536
#
#                    UNH           V         VZ        WBA        WMT
# 2021-10-25  427.258392  227.763489  42.104591  40.179771  47.608566
#
# [1 rows x 29 columns]

# %%
LastPrice = np.array([1/p for p in StockData.tail(1).to_numpy()[0]])
Initial_Portfolio = np.multiply(mvo_weights, LastPrice)
Initial_Portfolio
# Out:
# array([1576.051,    0.   ,    0.   ,    0.   ,    0.   ,  170.579,
#           0.   ,    0.   ,    0.   ,    0.   ,  892.597,    0.   ,
#           0.   ,    0.   ,    0.   ,    0.   ,    0.   ,   13.37 ,
#           0.   ,    0.   ,   69.253,  601.008,    0.   ,    0.   ,
#         539.486,  127.72 ,    0.   ,    0.   ,  822.331])

# %%
Portfolio_Assets = TradeData @ Initial_Portfolio
MVO_result = pd.DataFrame(Portfolio_Assets, columns=["Mean Var"])
MVO_result
# Out:
#                 Mean Var
# 2021-10-26  1.001476e+06
# 2021-10-27  1.000531e+06
# 2021-10-28  1.008048e+06
# 2021-10-29  1.009308e+06
# 2021-11-01  1.000507e+06
# ...                  ...
# 2023-02-21  9.218281e+05
# 2023-02-22  9.205346e+05
# 2023-02-23  9.252233e+05
# 2023-02-24  9.130041e+05
# 2023-02-27  9.141664e+05
#
# [336 rows x 1 columns]

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtesting Results
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
df_result_a2c = df_account_value_a2c.set_index(df_account_value_a2c.columns[0])
df_result_ddpg = df_account_value_ddpg.set_index(df_account_value_ddpg.columns[0])
df_result_td3 = df_account_value_td3.set_index(df_account_value_td3.columns[0])
df_result_ppo = df_account_value_ppo.set_index(df_account_value_ppo.columns[0])
df_result_sac = df_account_value_sac.set_index(df_account_value_sac.columns[0])
df_account_value_a2c.to_csv("df_account_value_a2c.csv")
#baseline stats
print("==============Get Baseline Stats===========")
df_dji_ = get_baseline(
        ticker="^DJI", 
        start = TRADE_START_DATE,
        end = TRADE_END_DATE)
stats = backtest_stats(df_dji_, value_col_name = 'close')
df_dji = pd.DataFrame()
df_dji['date'] = df_account_value_a2c['date']
df_dji['account_value'] = df_dji_['close'] / df_dji_['close'][0] * env_kwargs["initial_amount"]
df_dji.to_csv("df_dji.csv")
df_dji = df_dji.set_index(df_dji.columns[0])
df_dji.to_csv("df_dji+.csv")

result = pd.merge(df_result_a2c, df_result_ddpg, left_index=True, right_index=True, suffixes=('_a2c', '_ddpg'))
result = pd.merge(result, df_result_td3, left_index=True, right_index=True, suffixes=('', '_td3'))
result = pd.merge(result, df_result_ppo, left_index=True, right_index=True, suffixes=('', '_ppo'))
result = pd.merge(result, df_result_sac, left_index=True, right_index=True, suffixes=('', '_sac'))
result = pd.merge(result, MVO_result, left_index=True, right_index=True, suffixes=('', '_mvo'))
result = pd.merge(result, df_dji, left_index=True, right_index=True, suffixes=('', '_dji'))
result.columns = ['a2c', 'ddpg', 'td3', 'ppo', 'sac', 'mean var', 'dji']

print("result: ", result)
result.to_csv("result.csv")
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (354, 8)
# Annual return         -0.034876
# Cumulative returns    -0.048644
# Annual volatility      0.181612
# Sharpe ratio          -0.105351
# Calmar ratio          -0.158953
# Stability              0.280983
# Max drawdown          -0.219408
# Omega ratio            0.982546
# Sortino ratio         -0.146974
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.970602
# Daily value at risk   -0.022957
# dtype: float64
# result:                       a2c          ddpg           td3           ppo  \
# 2021-10-26  1.000841e+06  1.033769e+06  1.032950e+06  9.983464e+05
# 2021-10-27  9.937116e+05  1.022329e+06  1.027808e+06  9.952889e+05
# 2021-10-28  1.012204e+06  1.029502e+06  1.031269e+06  9.990127e+05
# 2021-10-29  1.009785e+06  1.028577e+06  1.037720e+06  9.996604e+05
# 2021-11-01  1.016451e+06  1.035143e+06  1.039991e+06  1.005486e+06
# ...                  ...           ...           ...           ...
# 2023-02-21  1.006651e+06  9.575966e+05  1.040239e+06  8.309977e+05
# 2023-02-22  1.002634e+06  9.565260e+05  1.036405e+06  8.287586e+05
# 2023-02-23  1.003613e+06  9.592921e+05  1.040165e+06  8.316268e+05
# 2023-02-24  9.946582e+05  9.491069e+05  1.025391e+06  8.169750e+05
# 2023-02-27  9.998093e+05  9.534800e+05  1.026244e+06  8.209155e+05
#
#                      sac      mean var           dji
# 2021-10-26  1.064210e+06  1.001476e+06  1.041671e+06
# 2021-10-27  1.061737e+06  1.000531e+06  1.033916e+06
# 2021-10-28  1.069717e+06  1.008048e+06  1.040902e+06
# 2021-10-29  1.074864e+06  1.009308e+06  1.043497e+06
# 2021-11-01  1.073548e+06  1.000507e+06  1.046244e+06
# ...                  ...           ...           ...
# 2023-02-21  1.129345e+06  9.218281e+05  9.651327e+05
# 2023-02-22  1.126058e+06  9.205346e+05  9.626710e+05
# 2023-02-23  1.132135e+06  9.252233e+05  9.658412e+05
# 2023-02-24  1.116218e+06  9.130041e+05  9.560240e+05
# 2023-02-27  1.116865e+06  9.141664e+05  9.581264e+05
#
# [336 rows x 7 columns]

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();
